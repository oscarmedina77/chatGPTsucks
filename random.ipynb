# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(2, 2)

# %%
ax[0][0]
# Out:
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(2, 2)
ax[0][0].plot([0, 1], [0, 1])
ax[0][1].plot([0, 1], [0, 1])
plt.show()

# %%
class State():
    def __init__(self, config):
        try:
            self.drawScore = config['drawScore']
        except:
            print("not found")
            self.drawScore = 0.5
        else:
            self.drawScore = config['drawScore']

# %%
config1 = {'episodeSteps': 1000, 'actTimeout': 2, 'runTimeout': 1200, 'columns': 7, 'rows': 6, 'inarow': 4, 'agentTimeout': 60, 'timeout': 2}
config1
# Out:
# {'episodeSteps': 1000,
#  'actTimeout': 2,
#  'runTimeout': 1200,
#  'columns': 7,
#  'rows': 6,
#  'inarow': 4,
#  'agentTimeout': 60,
#  'timeout': 2}

# %%
test1 = State(config1)
# Out:
# not found

# %%
test1.drawScore
# Out:
# 0.5

# %%
config2 = {'episodeSteps': 1000, 'actTimeout': 2, 'runTimeout': 1200, 'columns': 7, 'rows': 6, 'inarow': 4, 'agentTimeout': 60, 'timeout': 2, 'drawScore': 0.1}
config2
# Out:
# {'episodeSteps': 1000,
#  'actTimeout': 2,
#  'runTimeout': 1200,
#  'columns': 7,
#  'rows': 6,
#  'inarow': 4,
#  'agentTimeout': 60,
#  'timeout': 2,
#  'drawScore': 0.1}

# %%
config2['drawScore']
# Out:
# 0.1

# %%
test2 = State(config2)

# %%
test2.drawScore
# Out:
# 0.1

# %%
board = [2, 0, 2, 2, 2, 0, 2, 1, 0, 1, 2, 1, 0, 1, 2, 0, 2, 1, 1, 0, 2, 1, 0, 1, 1, 2, 1, 1, 2, 0, 2, 2, 1, 2, 1, 1, 0, 2, 1, 1, 2, 1]

# %%
len(board)
# Out:
# 42

# %%
split_list = np.split(np.array(board).T, 6)

# %%
split_list
# Out:
# [array([2, 0, 2, 2, 2, 0, 2]),
#  array([1, 0, 1, 2, 1, 0, 1]),
#  array([2, 0, 2, 1, 1, 0, 2]),
#  array([1, 0, 1, 1, 2, 1, 1]),
#  array([2, 0, 2, 2, 1, 2, 1]),
#  array([1, 0, 2, 1, 1, 2, 1])]
